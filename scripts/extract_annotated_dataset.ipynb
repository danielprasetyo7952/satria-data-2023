# %%
import cv2
import numpy as np
import os

# %% [markdown]
# ### bounding box format

# %%
# Load the image
image = cv2.imread("datatrain5.jpg")

# Load the annotations
annotations = np.loadtxt("datatrain1.txt")

for i, annotation in enumerate(annotations):
    # Extract the class label and bounding box coordinates
    class_label, x_center, y_center, width, height = annotation

    # Calculate the bounding box coordinates in pixels
    x1 = int((x_center - width / 2) * image.shape[1])
    y1 = int((y_center - height / 2) * image.shape[0])
    x2 = int((x_center + width / 2) * image.shape[1])
    y2 = int((y_center + height / 2) * image.shape[0])

    # Crop the image using the bounding box coordinates
    cropped_image = image[y1:y2, x1:x2]

    # Save the cropped image
    cv2.imwrite(f"cropped_rectangle_image_{i}.jpg", cropped_image)

# %% [markdown]
# ### polygon format

# %%
# Load the image
image = cv2.imread('datatrain5.jpg')

# Load the annotations
data = []
with open('datatrain5.txt', 'r') as f:
    for line in f:
        row = line.strip().split()
        data.append(row)

for i, d in enumerate(data):
    # Extract the class label and polygon coordinates
    class_label = int(data[i][0])
    polygon = np.array(data[i][1:], dtype=float).reshape(-1, 2)

    # Convert the polygon coordinates to integers
    polygon = np.round(polygon * np.array([image.shape[1], image.shape[0]])).astype(int)

    # Create a mask for the polygon
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    cv2.fillPoly(mask, [polygon], 255)

    # Find the bounding rectangle of the polygon
    x, y, w, h = cv2.boundingRect(polygon)

    # Crop the image using the bounding rectangle
    cropped_image = image[y:y+h, x:x+w]

    # Save the cropped image
    cv2.imwrite(f'cropped_poly_image_{i}.jpg', cropped_image)

# %% [markdown]
# ### read both

# %%
def extract_annotations(img_path, annotation_path, output_path):
    # Load the annotations
    data = []
    with open(annotation_path, 'r') as f:
        for line in f:
            row = line.strip().split()
            data.append(row)

    for i, annotation in enumerate(data):
        # Check if the current row has 5 values
        if len(annotation) == 5:
            # Call the function to extract bounding box annotations
            extract_bbox(img_path, annotation, output_path, i)
        else:
            # Call the function to extract polygon annotations
            extract_poly(img_path, annotation, output_path, i)


def extract_bbox(image_path: str, annotation: 'List[str]', base_output_path: str, i: int) -> None:
    # Load the image
    image = cv2.imread(image_path)

    # Extract the class label and bounding box coordinates
    class_label, x_center, y_center, width, height = map(float, annotation)

    class_label = str(int(class_label))

    # Calculate the bounding box coordinates in pixels
    x1 = int((x_center - width / 2) * image.shape[1])
    y1 = int((y_center - height / 2) * image.shape[0])
    x2 = int((x_center + width / 2) * image.shape[1])
    y2 = int((y_center + height / 2) * image.shape[0])

    # Crop the image using the bounding box coordinates
    cropped_image = image[y1:y2, x1:x2]

    # Create the class label folder if it doesn't exist
    class_folder = os.path.join(base_output_path, class_label)
    if not os.path.exists(class_folder):
        os.makedirs(class_folder)

    base_name = os.path.basename(image_path)
    img_output = os.path.join(class_folder, f"{base_name}-rectangle-{i}.jpg")

    print(f"saved in {img_output}")

    # Save the cropped image
    cv2.imwrite(img_output, cropped_image)


def extract_poly(image_path: str, annotation: 'List[str]', base_output_path: str, i: int) -> None:
    # Load the image
    image = cv2.imread(image_path)

    # Extract the class label and polygon coordinates
    class_label = int(annotation[0])
    polygon = np.array(annotation[1:], dtype=float).reshape(-1, 2)

    # Convert the polygon coordinates to integers
    polygon = np.round(polygon * np.array([image.shape[1], image.shape[0]])).astype(int)

    # Create a mask for the polygon
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    cv2.fillPoly(mask, [polygon], 255)

    # Find the bounding rectangle of the polygon
    x, y, w, h = cv2.boundingRect(polygon)

    # Crop the image using the bounding rectangle
    cropped_image = image[y:y+h, x:x+w]

    # Create the class label folder if it doesn't exist
    class_folder = os.path.join(base_output_path, str(class_label))
    if not os.path.exists(class_folder):
        os.makedirs(class_folder)

    base_name = os.path.basename(image_path)
    img_output = os.path.join(class_folder, f"{base_name}-polygon-{i}.jpg")

    print(f"saved in {img_output}")

    # Save the cropped image
    cv2.imwrite(img_output, cropped_image)

# %%
img_path = "datatrain5.jpg"
annotation_path = "datatrain5.txt"

extract_annotations(img_path, annotation_path, "./test")
# Out:
# saved in ./test\11\datatrain5-polygon-0.jpg
# saved in ./test\1\datatrain5-polygon-1.jpg
# saved in ./test\0\datatrain5-polygon-2.jpg
# saved in ./test\8\datatrain5-polygon-3.jpg
# saved in ./test\9\datatrain5-polygon-4.jpg
# saved in ./test\31\datatrain5-polygon-5.jpg
# saved in ./test\13\datatrain5-polygon-6.jpg

# %% [markdown]
# ## Extract All

# %%
error_list = []

# Set the base paths to the images and annotations folders
base_images_path = "./yolov8-dataset-v2/"
base_annotations_path = "./yolov8-dataset-v2/"

# Set the base path to the output folder
base_output_path = "./yolov8-dataset-v2-extracted/"

# Set the dataset splits
splits = ["train", "valid", "test"]

empty_labels = []
total_data = 0
total_empty = 0

# Loop through the dataset splits
for split in splits:
    # Set the paths to the images and annotations folders for the current split
    images_path = os.path.join(base_images_path, split, "images")
    annotations_path = os.path.join(base_annotations_path, split, "labels")

    # Set the path to the output folder for the current split
    output_path = os.path.join(base_output_path, split)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    empty_label = []

    # Loop through the annotation files
    for i, filename in enumerate(os.listdir(annotations_path)):
        
        print(f'reading: {filename}')
        
        annotation_file = os.path.join(annotations_path, filename)
        image_file = os.path.join(images_path, filename.replace(".txt", ".jpg"))
        
        if os.stat(annotation_file).st_size == 0:
            empty_label.append(annotation_file)
            total_empty += 1
            continue
        else:
            extract_annotations(image_file, annotation_file, output_path)
            total_data += 1
        
    print(f"total empty label in {split}: {len(empty_label)}")
    print()
    empty_labels.append(empty_label)

print(f'total empty labels: {total_empty}')
print(f'total extracted data: {total_data}')
# Out:
# reading: DataTrain100_png.rf.121b2a445bd9cbf7f452554772df2558.txt
# saved in ./yolov8-dataset-v2-extracted/train\10\DataTrain100_png.rf.121b2a445bd9cbf7f452554772df2558.jpg-rectangle-0.jpg
# saved in ./yolov8-dataset-v2-extracted/train\11\DataTrain100_png.rf.121b2a445bd9cbf7f452554772df2558.jpg-rectangle-1.jpg
# saved in ./yolov8-dataset-v2-extracted/train
DataTrain476_png.rf.84dc402f11d1e0e7f3baca5b5303bb31.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\15\DataTrain476_png.rf.84dc402f11d1e0e7f3baca5b5303bb31.jpg-polygon-7.jpg
# reading: DataTrain503_png.rf.8c4478376f7ef061c56d7d116ba87ec2.txt
# reading: DataTrain548_png.rf.6c66810a084feea845a0732005376e62.txt
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\2\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\2\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\5\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\15\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\18\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\28\DataTrain548_png.rf.6c66810a084feea845a0732005376e62.jpg-polygon-7.jpg
# reading: DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.txt
# saved in ./yolov8-dataset-v2-extracted/test\10\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\13\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\9\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\5\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\5\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\0\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\31\DataTrain56_png.rf.5a26f1b83166b930d1b5aa0a6f3ac54c.jpg-polygon-7.jpg
# reading: DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.txt
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\7\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\6\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\3\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\26\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\29\DataTrain583_png.rf.0ecd7bbb07e81d6a611a9115ff7cc939.jpg-polygon-6.jpg
# reading: DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.txt
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\2\DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\6\DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\19\DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\19\DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\29\DataTrain596_png.rf.6404009b54cb00e95f2cef77d78206c2.jpg-polygon-5.jpg
# reading: DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.txt
# saved in ./yolov8-dataset-v2-extracted/test\21\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\30\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\9\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\8\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain615_png.rf.53ffca3b210cea9239b770b32c4b0842.jpg-rectangle-6.jpg
# reading: DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.txt
# saved in ./yolov8-dataset-v2-extracted/test\29\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\21\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\32\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\5\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\9\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\8\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain646_png.rf.d49f17f732dc9faa41a4351897192ac1.jpg-polygon-7.jpg
# reading: DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.txt
# saved in ./yolov8-dataset-v2-extracted/test\10\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\8\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\8\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\6\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\15\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\13\DataTrain667_png.rf.c1c4de7f6506b29bb5d154fa9ec75147.jpg-polygon-7.jpg
# reading: DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.txt
# saved in ./yolov8-dataset-v2-extracted/test\13\DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\2\DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\3\DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain704_png.rf.bc5b8c2ab5e76cac9c89f7be03dcfb84.jpg-polygon-5.jpg
# reading: DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.txt
# saved in ./yolov8-dataset-v2-extracted/test\28\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\24\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\31\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\3\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\4\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\5\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain728_png.rf.d03034845e6b175be1027a4ab799f1d3.jpg-rectangle-7.jpg
# reading: DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.txt
# saved in ./yolov8-dataset-v2-extracted/test\21\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\35\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\28\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\0\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\3\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain729_png.rf.cd5bc3bc6bfdcdbafad747c59a8bd01b.jpg-rectangle-7.jpg
# reading: DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.txt
# saved in ./yolov8-dataset-v2-extracted/test\16\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\18\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\29\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\7\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\8\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain77_png.rf.8536700f505854c7a28b77a78b60c88a.jpg-polygon-7.jpg
# reading: DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.txt
# saved in ./yolov8-dataset-v2-extracted/test\10\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-0.jpg
# saved in ./yolov8-dataset-v2-extracted/test\11\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-1.jpg
# saved in ./yolov8-dataset-v2-extracted/test\6\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-2.jpg
# saved in ./yolov8-dataset-v2-extracted/test\9\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-3.jpg
# saved in ./yolov8-dataset-v2-extracted/test\4\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-4.jpg
# saved in ./yolov8-dataset-v2-extracted/test\1\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-5.jpg
# saved in ./yolov8-dataset-v2-extracted/test\19\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-6.jpg
# saved in ./yolov8-dataset-v2-extracted/test\14\DataTrain82_png.rf.b9bd6648c57437852ae151614bdc7704.jpg-polygon-7.jpg
# total empty label in test: 1
#
# total empty labels: 14
# total extracted data: 651
