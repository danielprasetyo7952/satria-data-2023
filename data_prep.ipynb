# %%
import os
import cv2
import pandas as pd

# %%
folder_path = './data-modified/train/data/'
csv_path = './data-modified/train/DataTrain.csv'

# Load labels from CSV file
labels_df = pd.read_csv(csv_path, delimiter=';')
labels = labels_df['Vehicleregistrationplate'].values

# Load images from folder
images = []
for filename in os.listdir(folder_path):
    img = cv2.imread(os.path.join(folder_path, filename))
    if img is not None:
        images.append(img)

# %%
images, labels
# Out:
# ([array([[[39, 30, 50],
#           [40, 31, 51],
#           [40, 31, 51],
#           ...,
#           [25, 21, 32],
#           [25, 21, 32],
#           [25, 21, 32]],
#
#          [[41, 32, 52],
#           [41, 32, 52],
#           [41, 32, 52],
#           ...,
#           [25, 21, 32],
#           [25, 21, 32],
#           [25, 21, 32]],
#
#          [[42, 33, 53],
#           [42, 33, 53],
#           [42, 33, 53],
#           ...,
#           [25, 21, 32],
#           [25, 21, 32],
#           [25, 21, 32]],
#
#          ...,
#
#          [[28, 23, 38],
#           [28, 23, 38],
#           [28, 23, 38],
#           ...,
#           [27, 22, 37],
#           [27, 22, 37],
#           [27, 22, 37]],
#
#          [[28, 23, 38],
#           [28, 23, 38],
#           [28, 23, 38],
#           ...,
#           [27, 22, 37],
#           [27, 22, 37],
#           [27, 22, 37]],
#
#          [[28, 23, 38],
#           [28, 23, 38],
#           [28, 23, 38],
#           ...,
#           [27, 22, 37],
#           [27, 22, 37],
#           [27, 22, 37]]], dtype=uint8),
#   array([[[212, 233, 255],
#           [215, 236, 255],
#           [218, 239, 255],
#           ...,
#           [166, 191, 225],
#           [167, 192, 226],
#           [169, 194, 228]],
#
#          [[222, 243, 255],
#           [223, 244, 255],
#           [224, 245, 255],
#           ...,
#           [169, 194, 228],
#           [168, 193, 227],
#           [167, 192, 226]],
#
#          [[207, 228, 250],
#           [207, 228, 250],
#           [207, 228, 250],
#           ...,
#           [173, 198, 232],
#           [166, 193, 227],
#           [163, 190, 224]],
#
#          ...,
#
#          [[ 89, 129, 164],
#           [ 88, 128, 163],
#           [ 87, 127, 162],
#           ...,
#           [ 99, 146, 184],
#           [ 95, 144, 184],
#           [ 94, 143, 183]],
#
#          [[ 88, 128, 163],
#           [ 87, 127, 162],
#           [ 87, 127, 162],
#           ...,
#           [ 92, 139, 177],
#           [ 89, 138, 178],
#           [ 89, 138, 178]],
#
#          [[ 84, 124, 159],
#           [ 84, 124, 159],
#           [ 85, 125, 160],
#           ...,
#           [ 87, 136, 174],
#           [ 87, 136, 176],
#           [ 88, 137, 177]]], dtype=uint8),
#   array([[[ 43,  51,  50],
#           [ 63,  71,  70],
#           [ 56,  64,  63],
#           ...,
#           [127,  74,   1],
#           [130,  73,   0],
#           [128,  72,   0]],
#
#          [[ 44,  50,  49],
#           [ 44,  50,  49],
#           [ 37,  43,  42],
#           ...,
#           [130,  76,   5],
#           [131,  76,   3],
#           [130,  75,   0]],
#
#          [[ 51,  56,  55],
#           [ 40,  45,  44],
#           [ 36,  41,  40],
#           ...,
#           [136,  84,  17],
#           [134,  82,  12],
#           [134,  82,  11]],
#
#          ...,
#
#          [[136, 124, 154],
#           [125, 112, 136],
#           [119, 106, 122],
#           ...,
#           [109,  80,  65],
#           [101,  69,  56],
#           [108,  76,  63]],
#
#          [[118, 107, 145],
#           [118, 107, 139],
#           [126, 111, 132],
#           ...,
#           [108,  77,  68],
#           [118,  84,  78],
#           [132,  97,  93]],
#
#          [[108,  97, 135],
#           [115, 104, 136],
#           [136, 121, 142],
#           ...,
#           [167, 136, 127],
#           [186, 152, 146],
#           [197, 162, 158]]], dtype=uint8),
#   array([[[ 25,  64,  79],
#           [ 24,  63,  78],
#           [ 24,  63,  78],
#           ...,
#           [ 24,  43,  50],
#           [ 25,  44,  51],
#           [ 25,  44,  51]],
#
#          [[ 31,  70,  85],
#           [ 28,  69,  84],
#           [ 30,  69,  84],
#           ...,
#           [ 23,  42,  49],
#           [ 22,  41,  49],
#           [ 22,  41,  48]],
#
#          [[ 33,  74,  89],
#           [ 31,  74,  89],
#           [ 32,  73,  88],
#           ...,
#           [ 17,  38,  46],
#           [ 19,  39,  50],
#           [ 19,  40,  48]],
#
#          ...,
#
#          [[157, 240, 248],
#           [157, 240, 248],
#           [157, 240, 248],
#           ...,
#           [152, 239, 249],
#           [152, 239, 249],
#           [152, 239, 249]],
#
#          [[155, 240, 248],
#           [155, 240, 248],
#           [155, 240, 248],
#           ...,
#           [149, 238, 248],
#           [151, 240, 250],
#           [151, 240, 250]],
#
#          [[155, 240, 248],
#           [155, 240, 248],
#           [155, 240, 248],
#           ...,
#           [148, 237, 247],
#           [152, 241, 251],
#           [152, 241, 251]]], dtype=uint8),
#   array([[[218, 240, 252],
#           [232, 254, 255],
#           [226, 248, 255],
#           ...,
#           [  6,  27,  49],
#           [  2,  23,  45],
#           [  0,  19,  41]],
#
#          [[ 23,  42,  55],
#           [ 13,  35,  47],
#           [ 29,  49,  60],
#           ...,
#           [126, 147, 169],
#           [121, 142, 164],
#           [117, 138, 159]],
#
#          [[ 41,  59,  70],
#           [  6,  26,  37],
#           [  0,  14,  25],
#           ...,
#           [166, 187, 208],
#           [169, 190, 211],
#           [172, 194, 212]],
#
#          ...,
#
#          [[ 11,  13,  21],
#           [  0,   0,   4],
#           [  0,   0,   6],
#           ...,
#           [117, 132, 141],
#           [162, 174, 184],
#           [178, 190, 200]],
#
#          [[ 20,  21,  31],
#           [ 17,  19,  27],
#           [  0,   0,  10],
#           ...,
#           [111, 126, 135],
#           [ 73,  85,  95],
#           [  0,   0,   8]],
#
#          [[ 22,  22,  34],
#           [ 40,  41,  51],
#           [ 19,  19,  31],
#           ...,
#           [ 29,  44,  53],
#           [  0,   5,  15],
#           [  0,   9,  19]]], dtype=uint8),
#   array([[[186, 186, 174],
#           [186, 186, 174],
#           [188, 188, 176],
#           ...,
#           [254, 253, 255],
#           [254, 253, 255],
#           [254, 253, 255]],
#
#          [[182, 182, 170],
#           [182, 182, 170],
#           [183, 183, 171],
#           ...,
#           [254, 253, 255],
#           [254, 253, 255],
#           [254, 253, 255]],
#
#          [[176, 176, 164],
#           [176, 176, 164],
#           [176, 176, 164],
#           ...,
#           [254, 253, 255],
#           [254, 253, 255],
#           [254, 253, 255]],
#
#          ...,
#
#          [[ 53,  48,  50],
#           [ 53,  48,  50],
#           [ 53,  48,  50],
#           ...,
#           [194, 194, 182],
#           [192, 192, 180],
#           [191, 191, 179]],
#
#          [[ 55,  50,  52],
#           [ 54,  49,  51],
#           [ 53,  48,  50],
#           ...,
#           [184, 183, 173],
#           [183, 182, 172],
#           [182, 181, 171]],
#
#          [[ 56,  51,  53],
#           [ 55,  50,  52],
#           [ 54,  49,  51],
#           ...,
#           [179, 178, 168],
#           [178, 177, 167],
#           [178, 177, 167]]], dtype=uint8),
#   array([[[112,  98,  92],
#           [115, 101,  95],
#           [118, 104,  98],
#           ...,
#           [181, 168, 154],
#           [181, 168, 154],
#           [182, 169, 155]],
#
#          [[113,  99,  93],
#           [116, 102,  96],
#           [119, 105,  99],
#           ...,
#           [181, 168, 154],
#           [181, 168, 154],
#           [182, 169, 155]],
#
#          [[115, 101,  95],
#           [117, 103,  97],
#           [120, 106, 100],
#           ...,
#           [181, 168, 154],
#           [181, 168, 154],
#           [181, 168, 154]],
#
#          ...,
#
#          [[ 46,  34,  40],
#           [ 46,  34,  40],
#           [ 46,  34,  40],
#           ...,
#           [149, 129, 118],
#           [143, 123, 112],
#           [139, 119, 108]],
#
#          [[ 46,  34,  40],
#           [ 46,  34,  40],
#           [ 46,  34,  40],
#           ...,
#           [152, 130, 118],
#           [145, 123, 111],
#           [140, 118, 106]],
#
#          [[ 45,  33,  39],
#           [ 45,  33,  39],
#           [ 45,  33,  39],
#           ...,
#           [152, 130, 118],
#           [145, 123, 111],
#           [140, 118, 106]]], dtype=uint8),
#   array([[[255, 213, 176],
#           [255, 213, 176],
#           [255, 214, 177],
#           ...,
#           [243, 213, 172],
#           [241, 211, 170],
#           [241, 211, 170]],
#
#          [[247, 205, 168],
#           [248, 206, 169],
#           [248, 206, 169],
#           ...,
#           [236, 206, 165],
#           [235, 205, 164],
#           [235, 205, 164]],
#
#          [[231, 191, 156],
#           [232, 192, 157],
#           [233, 193, 158],
#           ...,
#           [226, 195, 156],
#           [225, 194, 155],
#           [225, 194, 155]],
#
#          ...,
#
#          [[ 97,  80,  71],
#           [ 94,  77,  68],
#           [ 91,  74,  65],
#           ...,
#           [ 77,  59,  42],
#           [ 76,  58,  41],
#           [ 76,  58,  41]],
#
#          [[ 97,  78,  73],
#           [ 96,  77,  72],
#           [ 96,  77,  72],
#           ...,
#           [ 58,  42,  25],
#           [ 54,  38,  21],
#           [ 52,  36,  19]],
#
#          [[ 97,  78,  75],
#           [ 96,  77,  74],
#           [ 96,  77,  74],
#           ...,
#           [ 44,  28,  11],
#           [ 40,  24,   7],
#           [ 38,  22,   5]]], dtype=uint8),
#   array([[[ 37,  33,  32],
#           [ 58,  54,  53],
#           [ 65,  61,  60],
#           ...,
#           [ 46,  36,  36],
#           [ 52,  42,  42],
#           [ 50,  39,  41]],
#
#          [[ 45,  41,  40],
#           [ 55,  51,  50],
#           [ 54,  50,  49],
#           ...,
#           [ 51,  41,  41],
#           [ 38,  28,  28],
#           [ 46,  35,  37]],
#
#          [[ 48,  44,  43],
#           [ 55,  51,  50],
#           [ 58,  54,  53],
#           ...,
#           [ 57,  47,  47],
#           [ 42,  32,  32],
#           [ 44,  34,  34]],
#
#          ...,
#
#          [[ 72,  77,  80],
#           [ 98, 103, 106],
#           [110, 114, 115],
#           ...,
#           [ 44,  32,  32],
#           [ 43,  31,  31],
#           [ 50,  38,  38]],
#
#          [[ 53,  60,  63],
#           [ 75,  80,  83],
#           [ 82,  86,  87],
#           ...,
#           [ 45,  33,  33],
#           [ 44,  32,  32],
#           [ 47,  35,  35]],
#
#          [[100, 107, 110],
#           [ 78,  85,  88],
#           [ 57,  61,  62],
#           ...,
#           [ 46,  34,  34],
#           [ 45,  33,  33],
#           [ 47,  35,  35]]], dtype=uint8),
#   array([[[57, 47, 47],
#           [58, 48, 48],
#           [60, 50, 50],
#           ...,
#           [63, 51, 51],
#           [66, 54, 54],
#           [68, 56, 56]],
#
#          [[57, 47, 47],
#           [58, 48, 48],
#           [60, 50, 50],
#           ...,
#           [63, 51, 51],
#           [67, 55, 55],
#           [68, 56, 56]],
#
#          [[57, 47, 47],
#           [58, 48, 48],
#           [60, 50, 50],
#           ...,
#           [65, 53, 53],
#           [68, 56, 56],
#           [70, 58, 58]],
#
#          ...,
#
#          [[38, 26, 32],
#           [39, 27, 33],
#           [39, 27, 33],
#           ...,
#           [39, 33, 34],
#           [39, 33, 34],
#           [39, 33, 34]],
#
#          [[38, 26, 32],
#           [38, 26, 32],
#           [38, 26, 32],
#           ...,
#           [39, 33, 34],
#           [39, 33, 34],
#           [38, 32, 33]],
#
#          [[38, 26, 32],
#           [38, 26, 32],
#           [38, 26, 32],
#           ...,
#           [39, 33, 34],
#           [39, 33, 34],
#           [38, 32, 33]]], dtype=uint8),
#   array([[[ 53,  35,  42],
#           [ 94,  76,  83],
#           [104,  86,  93],
#           ...,
#           [ 68,  54,  58],
#           [ 67,  56,  59],
#           [ 82,  72,  78]],
#
#          [[ 72,  54,  61],
#           [105,  87,  94],
#           [110,  92,  99],
#           ...,
#           [ 59,  45,  49],
#           [ 81,  70,  73],
#           [ 93,  83,  89]],
#
#          [[ 85,  70,  74],
#           [113,  98, 102],
#           [126, 111, 115],
#           ...,
#           [ 57,  43,  47],
#           [ 71,  60,  63],
#           [101,  91,  97]],
#
#          ...,
#
#          [[110,  95, 103],
#           [116, 103, 111],
#           [159, 149, 155],
#           ...,
#           [ 89,  75,  76],
#           [ 65,  51,  52],
#           [ 68,  54,  55]],
#
#          [[114, 101, 109],
#           [119, 106, 114],
#           [158, 148, 154],
#           ...,
#           [ 99,  85,  86],
#           [ 78,  64,  65],
#           [ 88,  74,  75]],
#
#          [[123, 110, 118],
#           [120, 107, 115],
#           [142, 132, 138],
#           ...,
#           [ 77,  63,  64],
#           [ 79,  65,  66],
#           [ 90,  76,  77]]], dtype=uint8),
#   array([[[58, 51, 56],
#           [57, 50, 55],
#           [55, 48, 53],
#           ...,
#           [33, 21, 27],
#           [33, 21, 27],
#           [33, 21, 27]],
#
#          [[58, 51, 56],
#           [56, 49, 54],
#           [54, 47, 52],
#           ...,
#           [33, 21, 27],
#           [33, 21, 27],
#           [33, 21, 27]],
#
#          [[57, 50, 55],
#           [56, 49, 54],
#           [54, 47, 52],
#           ...,
#           [33, 21, 27],
#           [33, 21, 27],
#           [33, 21, 27]],
#
#          ...,
#
#          [[13, 12, 14],
#           [13, 12, 14],
#           [13, 12, 14],
#           ...,
#           [13, 12, 14],
#           [13, 12, 14],
#           [13, 12, 14]],
#
#          [[13, 12, 14],
#           [13, 12, 14],
#           [13, 12, 14],
#           ...,
#           [13, 12, 14],
#           [13, 12, 14],
#           [13, 12, 14]],
#
#          [[13, 12, 14],
#           [13, 12, 14],
#           [13, 12, 14],
#           ...,
#           [13, 12, 14],
#           [13, 12, 14],
#           [13, 12, 14]]], dtype=uint8),
#   array([[[ 97,  89,  89],
#           [ 99,  91,  91],
#           [101,  93,  93],
#           ...,
#           [130, 114, 107],
#           [130, 114, 107],
#           [130, 114, 107]],
#
#          [[ 92,  84,  84],
#           [ 94,  86,  86],
#           [ 96,  88,  88],
#           ...,
#           [130, 114, 107],
#           [130, 114, 107],
#           [130, 114, 107]],
#
#          [[ 82,  74,  74],
#           [ 84,  76,  76],
#           [ 86,  78,  78],
#           ...,
#           [122, 109, 101],
#           [122, 109, 101],
#           [122, 109, 101]],
#
#          ...,
#
#          [[ 37,  25,  31],
#           [ 37,  25,  31],
#           [ 37,  25,  31],
#           ...,
#           [ 30,  22,  29],
#           [ 31,  23,  30],
#           [ 32,  24,  31]],
#
#          [[ 38,  26,  32],
#           [ 38,  26,  32],
#           [ 38,  26,  32],
#           ...,
#           [ 35,  25,  31],
#           [ 35,  25,  31],
#           [ 35,  25,  31]],
#
#          [[ 38,  26,  32],
#           [ 38,  26,  32],
#           [ 38,  26,  32],
#           ...,
#           [ 37,  25,  31],
#           [ 37,  25,  31],
#           [ 37,  25,  31]]], dtype=uint8),
#   array([[[11,  6,  7],
#           [34, 29, 30],
#           [21, 16, 17],
#           ...,
#           [32, 24, 25],
#           [ 7,  0,  0],
#           [36, 28, 29]],
#
#          [[21, 16, 17],
#           [32, 27, 28],
#           [24, 19, 20],
#           ...,
#           [17,  9, 10],
#           [39, 31, 32],
#           [24, 16, 17]],
#
#          [[27, 22, 23],
#           [17, 12, 13],
#           [20, 15, 16],
#           ...,
#           [16,  8,  9],
#           [26, 18, 19],
#           [11,  3,  4]],
#
#          ...,
#
#          [[21, 15, 16],
#           [22, 16, 17],
#           [23, 18, 19],
#           ...,
#           [29, 23, 24],
#           [24, 18, 19],
#           [18, 12, 13]],
#
#          [[18, 12, 13],
#           [19, 13, 14],
#           [20, 15, 16],
#           ...,
#           [26, 20, 21],
#           [22, 16, 17],
#           [18, 12, 13]],
#
#          [[21, 15, 16],
#           [22, 16, 17],
#           [23, 18, 19],
#           ...,
#           [24, 18, 19],
#           [22, 16, 17],
#           [20, 14, 15]]], dtype=uint8),
#   array([[[ 50,  41,  38],
#           [ 54,  45,  42],
#           [ 61,  52,  49],
#           ...,
#           [121, 123, 117],
#           [116, 118, 112],
#           [116, 118, 112]],
#
#          [[ 50,  41,  38],
#           [ 55,  46,  43],
#           [ 62,  53,  50],
#           ...,
#           [119, 121, 115],
#           [116, 118, 112],
#           [116, 118, 112]],
#
#          [[ 48,  39,  36],
#           [ 53,  44,  41],
#           [ 60,  51,  48],
#           ...,
#           [118, 120, 114],
#           [117, 119, 113],
#           [117, 119, 113]],
#
#          ...,
#
#          [[ 46,  36,  36],
#           [ 46,  36,  36],
#           [ 46,  36,  36],
#           ...,
#           [ 52,  42,  42],
#           [ 51,  41,  41],
#           [ 51,  41,  41]],
#
#          [[ 52,  42,  42],
#           [ 52,  42,  42],
#           [ 51,  41,  41],
#           ...,
#           [ 54,  44,  44],
#           [ 53,  43,  43],
#           [ 53,  43,  43]],
#
#          [[ 55,  45,  45],
#           [ 55,  45,  45],
#           [ 55,  45,  45],
#           ...,
#           [ 55,  45,  45],
#           [ 54,  44,  44],
#           [ 54,  44,  44]]], dtype=uint8),
#   array([[[ 63,  94, 109],
#           [ 63,  94, 109],
#           [ 63,  94, 109],
#           ...,
#           [ 60,  90, 107],
#           [ 60,  90, 107],
#           [ 60,  90, 107]],
#
#          [[ 63,  94, 109],
#           [ 63,  94, 109],
#           [ 63,  94, 109],
#           ...,
#           [ 60,  90, 107],
#           [ 60,  90, 107],
#           [ 60,  90, 107]],
#
#          [[ 63,  94, 109],
#           [ 63,  94, 109],
#           [ 63,  94, 109],
#           ...,
#           [ 60,  90, 107],
#           [ 60,  90, 107],
#           [ 60,  90, 107]],
#
#          ...,
#
#          [[ 37,  36,  46],
#           [ 36,  35,  45],
#           [ 36,  35,  45],
#           ...,
#           [ 38,  36,  48],
#           [ 34,  32,  44],
#           [ 35,  33,  45]],
#
#          [[ 37,  36,  46],
#           [ 37,  36,  46],
#           [ 37,  36,  46],
#           ...,
#           [ 36,  35,  45],
#           [ 34,  33,  43],
#           [ 37,  36,  46]],
#
#          [[ 37,  36,  46],
#           [ 37,  36,  46],
#           [ 37,  36,  46],
#           ...,
#           [ 36,  35,  45],
#           [ 34,  33,  43],
#           [ 37,  36,  46]]], dtype=uint8),
#   array([[[58, 49, 46],
#           [58, 49, 46],
#           [57, 48, 45],
#           ...,
#           [58, 49, 46],
#           [60, 51, 48],
#           [62, 53, 50]],
#
#          [[60, 51, 48],
#           [59, 50, 47],
#           [57, 48, 45],
#           ...,
#           [55, 46, 43],
#           [57, 48, 45],
#           [59, 50, 47]],
#
#          [[60, 51, 48],
#           [59, 50, 47],
#           [57, 48, 45],
#           ...,
#           [54, 45, 42],
#           [55, 46, 43],
#           [56, 47, 44]],
#
#          ...,
#
#          [[50, 41, 38],
#           [51, 42, 39],
#           [53, 44, 41],
#           ...,
#           [61, 49, 49],
#           [61, 49, 49],
#           [61, 49, 49]],
#
#          [[61, 52, 48],
#           [60, 51, 47],
#           [60, 51, 47],
#           ...,
#           [64, 54, 54],
#           [62, 52, 52],
#           [61, 51, 51]],
#
#          [[63, 54, 50],
#           [62, 53, 49],
#           [62, 53, 49],
#           ...,
#           [64, 54, 54],
#           [62, 52, 52],
#           [61, 51, 51]]], dtype=uint8),
#   array([[[182, 156, 250],
#           [182, 156, 250],
#           [183, 157, 251],
#           ...,
#           [ 36,  27,  53],
#           [ 37,  28,  54],
#           [ 37,  28,  54]],
#
#          [[186, 159, 255],
#           [186, 159, 255],
#           [186, 159, 255],
#           ...,
#           [ 37,  28,  55],
#           [ 39,  30,  57],
#           [ 39,  30,  57]],
#
#          [[185, 160, 255],
#           [185, 160, 255],
#           [184, 159, 255],
#           ...,
#           [ 39,  31,  61],
#           [ 41,  33,  63],
#           [ 41,  33,  63]],
#
#          ...,
#
#          [[ 63,  56,  63],
#           [ 63,  56,  63],
#           [ 63,  56,  63],
#           ...,
#           [ 45,  41,  53],
#           [ 47,  43,  55],
#           [ 47,  43,  55]],
#
#          [[ 63,  56,  63],
#           [ 63,  56,  63],
#           [ 63,  56,  63],
#           ...,
#           [ 46,  42,  54],
#           [ 49,  44,  59],
#           [ 49,  44,  59]],
#
#          [[ 63,  56,  63],
#           [ 63,  56,  63],
#           [ 63,  56,  63],
#           ...,
#           [ 47,  43,  55],
#           [ 48,  43,  58],
#           [ 48,  43,  58]]], dtype=uint8),
#   array([[[142, 123, 116],
#           [141, 122, 115],
#           [140, 121, 114],
#           ...,
#           [149, 130, 123],
#           [149, 130, 123],
#           [149, 130, 123]],
#
#          [[142, 123, 116],
#           [142, 123, 116],
#           [141, 122, 115],
#           ...,
#           [148, 129, 122],
#           [148, 129, 122],
#           [148, 129, 122]],
#
#          [[142, 124, 117],
#           [142, 124, 117],
#           [140, 122, 115],
#           ...,
#           [146, 129, 120],
#           [146, 129, 120],
#           [146, 129, 120]],
#
#          ...,
#
#          [[ 52,  41,  43],
#           [ 52,  41,  43],
#           [ 53,  42,  44],
#           ...,
#           [ 65,  54,  56],
#           [ 68,  57,  59],
#           [ 70,  59,  61]],
#
#          [[ 53,  42,  44],
#           [ 53,  42,  44],
#           [ 53,  42,  44],
#           ...,
#           [ 63,  52,  54],
#           [ 64,  53,  55],
#           [ 64,  53,  55]],
#
#          [[ 54,  43,  45],
#           [ 54,  43,  45],
#           [ 54,  43,  45],
#           ...,
#           [ 60,  49,  51],
#           [ 60,  49,  51],
#           [ 59,  48,  50]]], dtype=uint8),
#   array([[[231, 235, 224],
#           [222, 226, 215],
#           [199, 198, 188],
#           ...,
#           [207, 203, 198],
#           [188, 183, 180],
#           [200, 195, 192]],
#
#          [[241, 245, 234],
#           [133, 137, 126],
#           [ 70,  69,  59],
#           ...,
#           [211, 207, 202],
#           [204, 199, 196],
#           [232, 227, 224]],
#
#          [[221, 225, 213],
#           [ 74,  78,  66],
#           [ 48,  48,  36],
#           ...,
#           [220, 214, 209],
#           [201, 196, 193],
#           [215, 210, 207]],
#
#          ...,
#
#          [[ 63,  65,  65],
#           [ 40,  42,  42],
#           [ 49,  51,  51],
#           ...,
#           [ 15,  14,  10],
#           [ 19,  19,  13],
#           [ 67,  67,  61]],
#
#          [[ 72,  74,  74],
#           [ 53,  55,  55],
#           [ 53,  55,  55],
#           ...,
#           [ 45,  44,  40],
#           [ 47,  47,  41],
#           [ 62,  62,  56]],
#
#          [[ 77,  79,  79],
#           [ 64,  66,  66],
#           [ 65,  67,  67],
#           ...,
#           [ 59,  58,  54],
#           [ 52,  52,  46],
#           [ 34,  34,  28]]], dtype=uint8),
#   array([[[78, 67, 69],
#           [78, 67, 69],
#           [81, 70, 72],
#           ...,
#           [65, 59, 60],
#           [65, 59, 60],
#           [64, 58, 59]],
#
#          [[83, 72, 74],
#           [83, 72, 74],
#           [84, 73, 75],
#           ...,
#           [63, 57, 58],
#           [63, 57, 58],
#           [63, 57, 58]],
#
#          [[87, 76, 78],
#           [86, 75, 77],
#           [86, 75, 77],
#           ...,
#           [60, 54, 55],
#           [61, 55, 56],
#           [61, 55, 56]],
#
#          ...,
#
#          [[50, 39, 41],
#           [50, 39, 41],
#           [49, 38, 40],
#           ...,
#           [78, 69, 66],
#           [77, 68, 65],
#           [76, 67, 64]],
#
#          [[55, 44, 46],
#           [55, 44, 46],
#           [54, 43, 45],
#           ...,
#           [81, 72, 69],
#           [80, 71, 68],
#           [80, 71, 68]],
#
#          [[56, 45, 47],
#           [55, 44, 46],
#           [55, 44, 46],
#           ...,
#           [81, 72, 69],
#           [81, 72, 69],
#           [81, 72, 69]]], dtype=uint8),
#   array([[[ 43,  37,  32],
#           [ 29,  23,  18],
#           [ 28,  20,  13],
#           ...,
#           [ 75,  58,  45],
#           [ 78,  61,  48],
#           [ 72,  55,  42]],
#
#          [[ 33,  27,  22],
#           [ 36,  30,  25],
#           [ 77,  69,  62],
#           ...,
#           [ 81,  64,  51],
#           [ 76,  59,  46],
#           [ 84,  67,  54]],
#
#          [[ 29,  24,  21],
#           [ 63,  57,  52],
#           [164, 156, 149],
#           ...,
#           [ 87,  70,  57],
#           [ 97,  80,  67],
#           [ 90,  73,  60]],
#
#          ...,
#
#          [[ 33,  30,  32],
#           [ 31,  28,  30],
#           [ 27,  24,  26],
#           ...,
#           [105,  93,  87],
#           [158, 148, 141],
#           [255, 252, 248]],
#
#          [[ 36,  33,  35],
#           [ 34,  31,  33],
#           [ 30,  27,  29],
#           ...,
#           [108,  96,  90],
#           [158, 148, 141],
#           [255, 252, 248]],
#
#          [[ 40,  37,  39],
#           [ 38,  35,  37],
#           [ 34,  31,  33],
#           ...,
#           [111,  99,  93],
#           [158, 148, 141],
#           [255, 252, 248]]], dtype=uint8),
#   array([[[ 62,  46, 223],
#           [ 62,  47, 222],
#           [ 61,  47, 219],
#           ...,
#           [223, 221, 227],
#           [210, 211, 215],
#           [205, 209, 210]],
#
#          [[ 61,  45, 222],
#           [ 60,  45, 220],
#           [ 60,  46, 218],
#           ...,
#           [215, 213, 219],
#           [198, 199, 203],
#           [194, 198, 199]],
#
#          [[ 60,  42, 219],
#           [ 60,  43, 218],
#           [ 58,  45, 215],
#           ...,
#           [200, 198, 204],
#           [181, 182, 186],
#           [177, 180, 184]],
#
#          ...,
#
#          [[ 67,  42, 252],
#           [ 68,  43, 253],
#           [ 69,  44, 254],
#           ...,
#           [ 48,  40,  51],
#           [ 49,  40,  53],
#           [ 49,  39,  55]],
#
#          [[ 65,  37, 250],
#           [ 66,  38, 251],
#           [ 68,  40, 253],
#           ...,
#           [ 49,  41,  51],
#           [ 50,  42,  53],
#           [ 50,  41,  54]],
#
#          [[ 67,  36, 251],
#           [ 68,  37, 252],
#           [ 70,  39, 254],
#           ...,
#           [ 49,  42,  49],
#           [ 50,  42,  53],
#           [ 50,  41,  54]]], dtype=uint8),
#   array([[[14, 12, 12],
#           [14, 12, 12],
#           [14, 12, 12],
#           ...,
#           [44, 37, 40],
#           [45, 38, 41],
#           [45, 38, 41]],
#
#          [[14, 12, 12],
#           [14, 12, 12],
#           [14, 12, 12],
#           ...,
#           [46, 39, 42],
#           [47, 40, 43],
#           [47, 40, 43]],
#
#          [[14, 12, 12],
#           [14, 12, 12],
#           [14, 12, 12],
#           ...,
#           [48, 41, 44],
#           [49, 42, 45],
#           [50, 43, 46]],
#
#          ...,
#
#          [[14, 12, 12],
#           [14, 12, 12],
#           [14, 12, 12],
#           ...,
#           [81, 86, 89],
#           [81, 86, 87],
#           [81, 86, 87]],
#
#          [[14, 12, 12],
#           [14, 12, 12],
#           [14, 12, 12],
#           ...,
#           [79, 84, 87],
#           [79, 84, 85],
#           [79, 84, 85]],
#
#          [[14, 12, 12],
#           [14, 12, 12],
#           [14, 12, 12],
#           ...,
#           [78, 83, 86],
#           [78, 83, 84],
#           [78, 83, 84]]], dtype=uint8),
#   array([[[67, 61, 62],
#           [67, 61, 62],
#           [67, 61, 62],
#           ...,
#           [50, 43, 46],
#           [50, 43, 46],
#           [51, 44, 47]],
#
#          [[67, 61, 62],
#           [67, 61, 62],
#           [67, 61, 62],
#           ...,
#           [54, 47, 50],
#           [54, 47, 50],
#           [53, 46, 49]],
#
#          [[67, 61, 62],
#           [67, 61, 62],
#           [67, 61, 62],
#           ...,
#           [59, 52, 55],
#           [58, 51, 54],
#           [58, 51, 54]],
#
#          ...,
#
#          [[64, 58, 63],
#           [63, 57, 62],
#           [64, 58, 63],
#           ...,
#           [95, 94, 90],
#           [96, 95, 91],
#           [97, 96, 92]],
#
#          [[57, 50, 57],
#           [53, 46, 53],
#           [51, 44, 51],
#           ...,
#           [95, 94, 90],
#           [96, 95, 91],
#           [96, 95, 91]],
#
#          [[54, 47, 54],
#           [49, 42, 49],
#           [44, 37, 44],
#           ...,
#           [94, 93, 89],
#           [95, 94, 90],
#           [96, 95, 91]]], dtype=uint8),
#   array([[[ 52,  41,  37],
#           [ 57,  46,  42],
#           [ 64,  53,  49],
#           ...,
#           [106, 105, 107],
#           [107, 107, 107],
#           [104, 105, 103]],
#
#          [[ 59,  48,  44],
#           [ 60,  49,  45],
#           [ 62,  51,  47],
#           ...,
#           [107, 106, 108],
#           [ 95,  95,  95],
#           [ 94,  95,  93]],
#
#          [[ 64,  53,  49],
#           [ 61,  50,  46],
#           [ 58,  47,  43],
#           ...,
#           [ 92,  91,  93],
#           [ 88,  88,  88],
#           [ 89,  90,  88]],
#
#          ...,
#
#          [[ 59,  55,  54],
#           [ 55,  51,  50],
#           [ 52,  48,  47],
#           ...,
#           [ 56,  53,  45],
#           [ 46,  44,  36],
#           [ 44,  42,  34]],
#
#          [[ 63,  59,  58],
#           [ 58,  54,  53],
#           [ 58,  54,  53],
#           ...,
#           [ 56,  53,  45],
#           [ 50,  48,  40],
#           [ 48,  46,  38]],
#
#          [[ 79,  75,  74],
#           [ 73,  69,  68],
#           [ 76,  72,  71],
#           ...,
#           [ 57,  54,  46],
#           [ 54,  52,  44],
#           [ 52,  50,  42]]], dtype=uint8),
#   array([[[ 40,  32,  19],
#           [ 26,  18,   5],
#           [ 25,  16,   6],
#           ...,
#           [ 26,  19,  10],
#           [ 45,  37,  30],
#           [ 35,  27,  20]],
#
#          [[ 50,  42,  29],
#           [ 43,  34,  24],
#           [ 40,  31,  21],
#           ...,
#           [ 59,  53,  46],
#           [ 68,  60,  53],
#           [ 44,  38,  31]],
#
#          [[ 64,  58,  47],
#           [ 59,  53,  42],
#           [ 47,  40,  31],
#           ...,
#           [ 86,  82,  77],
#           [ 88,  82,  77],
#           [ 51,  47,  42]],
#
#          ...,
#
#          [[ 30,  39,  36],
#           [ 85,  94,  91],
#           [ 87,  95,  94],
#           ...,
#           [ 79,  71,  64],
#           [ 70,  60,  53],
#           [ 71,  61,  54]],
#
#          [[ 24,  33,  30],
#           [ 84,  93,  90],
#           [ 92, 100,  99],
#           ...,
#           [ 51,  43,  36],
#           [ 59,  49,  42],
#           [ 58,  48,  41]],
#
#          [[ 25,  34,  31],
#           [ 90,  99,  96],
#           [105, 113, 112],
#           ...,
#           [ 48,  40,  33],
#           [ 46,  36,  29],
#           [ 44,  34,  27]]], dtype=uint8),
#   array([[[ 79,  62,  49],
#           [ 74,  58,  45],
#           [ 74,  59,  50],
#           ...,
#           [ 64,  47,  44],
#           [ 48,  31,  28],
#           [109,  92,  89]],
#
#          [[ 67,  51,  39],
#           [ 66,  52,  40],
#           [ 83,  73,  63],
#           ...,
#           [ 59,  42,  39],
#           [ 58,  41,  38],
#           [131, 114, 111]],
#
#          [[ 68,  58,  48],
#           [ 90,  81,  71],
#           [126, 121, 112],
#           ...,
#           [ 50,  33,  30],
#           [ 69,  52,  49],
#           [152, 135, 132]],
#
#          ...,
#
#          [[ 66,  48,  47],
#           [ 72,  54,  53],
#           [103,  88,  86],
#           ...,
#           [127, 122, 113],
#           [125, 109,  92],
#           [130, 109,  88]],
#
#          [[ 84,  66,  65],
#           [ 85,  67,  66],
#           [103,  88,  86],
#           ...,
#           [114, 111,  97],
#           [108,  94,  72],
#           [110,  90,  65]],
#
#          [[ 90,  72,  71],
#           [ 87,  69,  68],
#           [ 98,  83,  81],
#           ...,
#           [ 73,  70,  55],
#           [106,  92,  69],
#           [121, 102,  75]]], dtype=uint8),
#   array([[[57, 48, 45],
#           [60, 51, 48],
#           [64, 55, 52],
#           ...,
#           [52, 41, 43],
#           [51, 40, 42],
#           [51, 40, 42]],
#
#          [[53, 44, 41],
#           [55, 46, 43],
#           [58, 49, 46],
#           ...,
#           [51, 40, 42],
#           [50, 39, 41],
#           [50, 39, 41]],
#
#          [[46, 37, 34],
#           [46, 37, 34],
#           [46, 37, 34],
#           ...,
#           [50, 39, 41],
#           [49, 38, 40],
#           [49, 38, 40]],
#
#          ...,
#
#          [[50, 41, 38],
#           [50, 41, 38],
#           [50, 41, 38],
#           ...,
#           [68, 59, 56],
#           [69, 60, 57],
#           [70, 61, 58]],
#
#          [[49, 40, 37],
#           [50, 41, 38],
#           [50, 41, 38],
#           ...,
#           [70, 61, 58],
#           [70, 61, 58],
#           [69, 60, 57]],
#
#          [[49, 40, 37],
#           [50, 41, 38],
#           [50, 41, 38],
#           ...,
#           [70, 61, 58],
#           [70, 61, 58],
#           [69, 60, 57]]], dtype=uint8),
#   array([[[ 50,  49,  59],
#           [ 53,  52,  62],
#           [ 55,  54,  64],
#           ...,
#           [236, 241, 244],
#           [236, 241, 244],
#           [236, 241, 244]],
#
#          [[ 54,  53,  63],
#           [ 56,  55,  65],
#           [ 56,  55,  65],
#           ...,
#           [234, 239, 242],
#           [233, 238, 241],
#           [234, 239, 242]],
#
#          [[ 60,  59,  69],
#           [ 60,  59,  69],
#           [ 58,  57,  67],
#           ...,
#           [217, 222, 225],
#           [217, 222, 225],
#           [217, 222, 225]],
#
#          ...,
#
#          [[ 12,  12,  12],
#           [ 12,  12,  12],
#           [ 12,  12,  12],
#           ...,
#           [ 14,  12,  12],
#           [ 14,  12,  12],
#           [ 14,  12,  12]],
#
#          [[ 12,  12,  12],
#           [ 12,  12,  12],
#           [ 12,  12,  12],
#           ...,
#           [ 15,  13,  13],
#           [ 15,  13,  13],
#           [ 15,  13,  13]],
#
#          [[ 12,  12,  12],
#           [ 12,  12,  12],
#           [ 12,  12,  12],
#           ...,
#           [ 15,  13,  13],
#           [ 15,  13,  13],
#           [ 15,  13,  13]]], dtype=uint8),
#   array([[[ 49,  54,  69],
#           [ 48,  53,  68],
#           [ 48,  53,  68],
#           ...,
#           [ 46,  44,  43],
#           [ 46,  44,  43],
#           [ 46,  44,  43]],
#
#          [[ 49,  54,  69],
#           [ 49,  54,  69],
#           [ 49,  54,  69],
#           ...,
#           [ 46,  44,  43],
#           [ 46,  44,  43],
#           [ 46,  44,  43]],
#
#          [[ 49,  54,  69],
#           [ 50,  55,  70],
#           [ 50,  55,  70],
#           ...,
#           [ 46,  44,  43],
#           [ 46,  44,  43],
#           [ 46,  44,  43]],
#
#          ...,
#
#          [[ 91,  92, 102],
#           [ 92,  93, 103],
#           [ 95,  96, 106],
#           ...,
#           [ 51,  50,  54],
#           [ 51,  50,  54],
#           [ 51,  50,  54]],
#
#          [[ 93,  94, 104],
#           [ 94,  95, 105],
#           [ 96,  97, 107],
#           ...,
#           [ 49,  48,  52],
#           [ 49,  48,  52],
#           [ 49,  48,  52]],
#
#          [[ 92,  93, 103],
#           [ 93,  94, 104],
#           [ 95,  96, 106],
#           ...,
#           [ 48,  47,  51],
#           [ 48,  47,  51],
#           [ 47,  46,  50]]], dtype=uint8),
#   array([[[ 99, 101, 102],
#           [ 44,  46,  47],
#           [  4,   6,   7],
#           ...,
#           [  8,   8,   8],
#           [ 66,  66,  66],
#           [148, 148, 148]],
#
#          [[ 87,  89,  90],
#           [ 39,  41,  42],
#           [  7,   9,  10],
#           ...,
#           [ 37,  37,  37],
#           [ 31,  31,  31],
#           [147, 147, 147]],
#
#          [[ 77,  79,  80],
#           [ 34,  36,  37],
#           [ 12,  14,  15],
#           ...,
#           [ 39,  39,  39],
#           [ 28,  28,  28],
#           [137, 137, 137]],
#
#          ...,
#
#          [[ 18,  13,  15],
#           [ 25,  20,  22],
#           [ 33,  28,  30],
#           ...,
#           [ 18,  17,  19],
#           [ 16,  15,  17],
#           [ 25,  22,  24]],
#
#          [[ 19,  14,  16],
#           [ 22,  17,  19],
#           [ 27,  22,  24],
#           ...,
#           [ 22,  19,  21],
#           [ 20,  17,  19],
#           [ 27,  24,  26]],
#
#          [[ 22,  17,  19],
#           [ 22,  17,  19],
#           [ 22,  17,  19],
#           ...,
#           [ 27,  24,  26],
#           [ 26,  23,  25],
#           [ 31,  28,  30]]], dtype=uint8),
#   array([[[177, 156, 154],
#           [176, 155, 153],
#           [176, 155, 153],
#           ...,
#           [215, 198, 189],
#           [215, 198, 189],
#           [214, 197, 188]],
#
#          [[185, 164, 162],
#           [184, 163, 161],
#           [184, 163, 161],
#           ...,
#           [207, 190, 181],
#           [208, 191, 182],
#           [208, 191, 182]],
#
#          [[198, 179, 176],
#           [197, 178, 175],
#           [196, 177, 174],
#           ...,
#           [192, 177, 168],
#           [193, 178, 169],
#           [194, 179, 170]],
#
#          ...,
#
#          [[102,  90,  88],
#           [101,  89,  87],
#           [100,  88,  86],
#           ...,
#           [ 81,  74,  65],
#           [ 83,  76,  67],
#           [ 84,  77,  68]],
#
#          [[113, 100,  98],
#           [113, 100,  98],
#           [112,  99,  97],
#           ...,
#           [109,  99,  92],
#           [110, 100,  93],
#           [110, 100,  93]],
#
#          [[116, 103, 101],
#           [116, 103, 101],
#           [116, 103, 101],
#           ...,
#           [124, 114, 107],
#           [124, 114, 107],
#           [125, 115, 108]]], dtype=uint8),
#   array([[[ 23,  20,  15],
#           [  6,   3,   0],
#           [  7,   4,   0],
#           ...,
#           [ 11,  11,  11],
#           [ 10,  10,  10],
#           [  9,   9,   9]],
#
#          [[ 11,   8,   4],
#           [ 10,   7,   3],
#           [ 28,  25,  21],
#           ...,
#           [ 10,  10,  10],
#           [  9,   9,   9],
#           [  9,   9,   9]],
#
#          [[ 29,  25,  24],
#           [ 24,  20,  19],
#           [ 18,  14,  13],
#           ...,
#           [  8,   8,   8],
#           [  8,   8,   8],
#           [  8,   8,   8]],
#
#          ...,
#
#          [[107, 100, 107],
#           [107, 101, 106],
#           [115, 108, 111],
#           ...,
#           [ 10,   8,   7],
#           [ 11,   9,   8],
#           [ 61,  59,  58]],
#
#          [[102,  95, 102],
#           [ 96,  90,  95],
#           [ 99,  92,  97],
#           ...,
#           [ 13,  11,  10],
#           [ 19,  17,  16],
#           [ 73,  71,  70]],
#
#          [[ 77,  70,  77],
#           [ 65,  59,  64],
#           [ 62,  55,  60],
#           ...,
#           [ 11,   9,   8],
#           [ 18,  16,  15],
#           [ 76,  74,  73]]], dtype=uint8),
#   array([[[ 40,  34,  35],
#           [ 41,  35,  36],
#           [ 21,  15,  16],
#           ...,
#           [ 12,   7,   6],
#           [ 32,  27,  26],
#           [ 22,  17,  16]],
#
#          [[ 27,  21,  22],
#           [ 14,   8,   9],
#           [ 31,  25,  26],
#           ...,
#           [ 33,  28,  27],
#           [ 17,  12,  11],
#           [ 31,  26,  25]],
#
#          [[ 36,  31,  32],
#           [ 72,  67,  68],
#           [108, 103, 104],
#           ...,
#           [ 70,  65,  64],
#           [ 63,  58,  57],
#           [ 80,  75,  74]],
#
#          ...,
#
#          [[ 34,  26,  27],
#           [ 39,  31,  32],
#           [ 64,  56,  57],
#           ...,
#           [ 90,  85,  84],
#           [ 81,  76,  75],
#           [ 85,  80,  79]],
#
#          [[ 40,  34,  35],
#           [ 39,  33,  34],
#           [ 58,  52,  53],
#           ...,
#           [ 72,  67,  66],
#           [ 64,  59,  58],
#           [ 74,  69,  68]],
#
#          [[ 43,  37,  38],
#           [ 35,  29,  30],
#           [ 46,  40,  41],
#           ...,
#           [ 40,  35,  34],
#           [ 34,  29,  28],
#           [ 51,  46,  45]]], dtype=uint8),
#   array([[[ 79,  80,  76],
#           [ 89,  90,  86],
#           [ 78,  75,  71],
#           ...,
#           [118, 120, 121],
#           [147, 151, 152],
#           [181, 187, 192]],
#
#          [[ 57,  58,  54],
#           [ 77,  78,  74],
#           [ 86,  83,  79],
#           ...,
#           [147, 146, 148],
#           [115, 117, 118],
#           [127, 132, 135]],
#
#          [[ 59,  61,  55],
#           [ 73,  75,  69],
#           [ 84,  81,  77],
#           ...,
#           [166, 164, 164],
#           [138, 137, 139],
#           [131, 135, 136]],
#
#          ...,
#
#          [[ 57,  47,  40],
#           [ 59,  49,  42],
#           [ 65,  53,  47],
#           ...,
#           [230, 224, 217],
#           [255, 255, 247],
#           [255, 255, 250]],
#
#          [[ 65,  55,  48],
#           [ 67,  57,  50],
#           [ 75,  63,  57],
#           ...,
#           [248, 245, 237],
#           [255, 252, 247],
#           [255, 255, 251]],
#
#          [[ 72,  62,  55],
#           [ 81,  71,  64],
#           [ 86,  74,  68],
#           ...,
#           [255, 255, 249],
#           [252, 249, 244],
#           [255, 255, 251]]], dtype=uint8),
#   array([[[ 93,  75, 242],
#           [ 93,  75, 242],
#           [ 92,  74, 241],
#           ...,
#           [138, 124, 242],
#           [138, 124, 242],
#           [138, 124, 242]],
#
#          [[ 90,  72, 239],
#           [ 90,  72, 239],
#           [ 90,  72, 239],
#           ...,
#           [148, 134, 246],
#           [149, 135, 247],
#           [149, 135, 247]],
#
#          [[ 91,  70, 239],
#           [ 91,  70, 239],
#           [ 91,  70, 239],
#           ...,
#           [164, 150, 251],
#           [166, 152, 253],
#           [166, 152, 253]],
#
#          ...,
#
#          [[ 49,  45,  56],
#           [ 48,  44,  55],
#           [ 48,  44,  55],
#           ...,
#           [ 50,  48,  54],
#           [ 48,  46,  52],
#           [ 47,  45,  51]],
#
#          [[ 51,  47,  58],
#           [ 50,  46,  57],
#           [ 50,  46,  57],
#           ...,
#           [ 46,  44,  50],
#           [ 43,  41,  47],
#           [ 42,  40,  46]],
#
#          [[ 51,  47,  58],
#           [ 51,  47,  58],
#           [ 50,  46,  57],
#           ...,
#           [ 44,  42,  48],
#           [ 41,  39,  45],
#           [ 39,  37,  43]]], dtype=uint8),
#   array([[[128, 118, 118],
#           [131, 121, 121],
#           [137, 127, 127],
#           ...,
#           [ 60,  48,  46],
#           [ 60,  48,  46],
#           [ 60,  48,  46]],
#
#          [[125, 115, 115],
#           [126, 116, 116],
#           [129, 119, 119],
#           ...,
#           [ 60,  48,  46],
#           [ 60,  48,  46],
#           [ 60,  48,  46]],
#
#          [[118, 106, 104],
#           [119, 107, 105],
#           [120, 108, 106],
#           ...,
#           [ 60,  48,  46],
#           [ 60,  48,  46],
#           [ 60,  48,  46]],
#
#          ...,
#
#          [[ 91,  82,  79],
#           [ 93,  84,  81],
#           [ 96,  87,  84],
#           ...,
#           [ 36,  27,  24],
#           [ 36,  27,  24],
#           [ 36,  27,  24]],
#
#          [[ 75,  66,  63],
#           [ 76,  67,  64],
#           [ 79,  70,  67],
#           ...,
#           [ 40,  31,  28],
#           [ 40,  31,  28],
#           [ 40,  31,  28]],
#
#          [[ 67,  58,  55],
#           [ 67,  58,  55],
#           [ 69,  60,  57],
#           ...,
#           [ 46,  37,  34],
#           [ 45,  36,  33],
#           [ 45,  36,  33]]], dtype=uint8),
#   array([[[ 63,  51,  57],
#           [ 65,  53,  59],
#           [ 68,  56,  62],
#           ...,
#           [241, 239, 239],
#           [239, 237, 237],
#           [238, 236, 236]],
#
#          [[ 66,  54,  60],
#           [ 68,  56,  62],
#           [ 70,  58,  64],
#           ...,
#           [245, 243, 243],
#           [243, 241, 241],
#           [243, 241, 241]],
#
#          [[ 71,  59,  65],
#           [ 72,  60,  66],
#           [ 74,  62,  68],
#           ...,
#           [250, 248, 248],
#           [250, 248, 248],
#           [249, 247, 247]],
#
#          ...,
#
#          [[119, 100,  92],
#           [119, 100,  92],
#           [119, 100,  92],
#           ...,
#           [ 39,  33,  38],
#           [ 38,  32,  37],
#           [ 38,  32,  37]],
#
#          [[119, 100,  92],
#           [119, 100,  92],
#           [119, 100,  92],
#           ...,
#           [ 40,  34,  39],
#           [ 40,  34,  39],
#           [ 40,  34,  39]],
#
#          [[119, 100,  92],
#           [119, 100,  92],
#           [119, 100,  92],
#           ...,
#           [ 42,  36,  41],
#           [ 41,  35,  40],
#           [ 41,  35,  40]]], dtype=uint8),
#   array([[[ 76,  72,  71],
#           [ 73,  69,  68],
#           [ 69,  65,  64],
#           ...,
#           [ 63,  61,  61],
#           [ 64,  62,  62],
#           [ 62,  60,  60]],
#
#          [[ 74,  70,  69],
#           [ 71,  67,  66],
#           [ 67,  63,  62],
#           ...,
#           [ 63,  61,  61],
#           [ 63,  61,  61],
#           [ 61,  59,  59]],
#
#          [[ 71,  67,  66],
#           [ 68,  64,  63],
#           [ 65,  61,  60],
#           ...,
#           [ 65,  63,  63],
#           [ 63,  61,  61],
#           [ 61,  59,  59]],
#
#          ...,
#
#          [[102, 113, 117],
#           [101, 112, 116],
#           [100, 111, 115],
#           ...,
#           [ 85, 151, 162],
#           [ 82, 148, 159],
#           [ 82, 148, 159]],
#
#          [[102, 113, 117],
#           [101, 112, 116],
#           [100, 111, 115],
#           ...,
#           [ 71, 135, 146],
#           [ 67, 131, 142],
#           [ 66, 130, 141]],
#
#          [[101, 112, 116],
#           [101, 112, 116],
#           [ 99, 110, 114],
#           ...,
#           [ 63, 127, 138],
#           [ 58, 122, 133],
#           [ 55, 119, 130]]], dtype=uint8),
#   array([[[ 69,  59,  59],
#           [ 70,  60,  60],
#           [ 71,  61,  61],
#           ...,
#           [ 64,  54,  54],
#           [ 63,  53,  53],
#           [ 63,  53,  53]],
#
#          [[ 63,  53,  53],
#           [ 64,  54,  54],
#           [ 65,  55,  55],
#           ...,
#           [ 66,  56,  56],
#           [ 65,  55,  55],
#           [ 65,  55,  55]],
#
#          [[ 56,  46,  46],
#           [ 57,  47,  47],
#           [ 57,  47,  47],
#           ...,
#           [ 70,  60,  60],
#           [ 72,  62,  62],
#           [ 72,  62,  62]],
#
#          ...,
#
#          [[112, 107,  92],
#           [110, 105,  90],
#           [107, 102,  87],
#           ...,
#           [ 50,  39,  41],
#           [ 49,  38,  40],
#           [ 49,  38,  40]],
#
#          [[132, 126, 113],
#           [131, 125, 112],
#           [128, 122, 109],
#           ...,
#           [ 51,  40,  42],
#           [ 51,  40,  42],
#           [ 51,  40,  42]],
#
#          [[144, 138, 125],
#           [143, 137, 124],
#           [140, 134, 123],
#           ...,
#           [ 51,  40,  42],
#           [ 53,  42,  44],
#           [ 53,  42,  44]]], dtype=uint8),
#   array([[[255, 255, 122],
#           [255, 255, 122],
#           [255, 255, 122],
#           ...,
#           [255, 255, 112],
#           [255, 255, 112],
#           [255, 255, 112]],
#
#          [[255, 255, 122],
#           [255, 255, 122],
#           [255, 255, 122],
#           ...,
#           [255, 255, 112],
#           [255, 255, 112],
#           [255, 255, 112]],
#
#          [[255, 255, 122],
#           [255, 255, 122],
#           [255, 255, 122],
#           ...,
#           [255, 255, 112],
#           [255, 255, 112],
#           [255, 255, 112]],
#
#          ...,
#
#          [[242, 242,  94],
#           [243, 243,  95],
#           [245, 246,  96],
#           ...,
#           [143, 152,  35],
#           [142, 150,  33],
#           [141, 149,  32]],
#
#          [[213, 213,  65],
#           [216, 216,  68],
#           [220, 221,  71],
#           ...,
#           [119, 128,  11],
#           [118, 126,   9],
#           [116, 124,   7]],
#
#          [[192, 192,  44],
#           [196, 196,  48],
#           [201, 202,  52],
#           ...,
#           [110, 119,   2],
#           [109, 117,   0],
#           [108, 116,   0]]], dtype=uint8),
#   array([[[226, 221, 112],
#           [227, 222, 113],
#           [230, 223, 114],
#           ...,
#           [230, 214, 108],
#           [229, 213, 107],
#           [228, 212, 106]],
#
#          [[231, 224, 115],
#           [232, 225, 114],
#           [232, 225, 116],
#           ...,
#           [230, 214, 108],
#           [229, 213, 107],
#           [229, 213, 107]],
#
#          [[235, 226, 115],
#           [235, 227, 114],
#           [235, 226, 115],
#           ...,
#           [231, 217, 111],
#           [232, 218, 112],
#           [233, 219, 113]],
#
#          ...,
#
#          [[254, 254, 148],
#           [253, 253, 145],
#           [254, 253, 143],
#           ...,
#           [238, 218, 109],
#           [236, 216, 107],
#           [233, 213, 104]],
#
#          [[255, 254, 150],
#           [254, 254, 148],
#           [253, 254, 144],
#           ...,
#           [236, 216, 107],
#           [234, 214, 105],
#           [232, 212, 103]],
#
#          [[255, 254, 150],
#           [254, 254, 148],
#           [253, 253, 145],
#           ...,
#           [236, 216, 107],
#           [234, 214, 105],
#           [232, 212, 103]]], dtype=uint8),
#   array([[[ 28,  23,  24],
#           [ 27,  22,  23],
#           [ 26,  21,  22],
#           ...,
#           [169, 165, 164],
#           [172, 168, 167],
#           [175, 170, 171]],
#
#          [[ 31,  26,  27],
#           [ 30,  25,  26],
#           [ 28,  23,  24],
#           ...,
#           [145, 141, 140],
#           [147, 143, 142],
#           [149, 144, 145]],
#
#          [[ 33,  28,  29],
#           [ 32,  27,  28],
#           [ 31,  26,  27],
#           ...,
#           [138, 134, 133],
#           [140, 136, 135],
#           [141, 136, 137]],
#
#          ...,
#
#          [[ 11,   9,   8],
#           [ 11,   9,   8],
#           [ 11,   9,   8],
#           ...,
#           [187, 186, 190],
#           [184, 183, 187],
#           [180, 179, 183]],
#
#          [[ 14,  12,  11],
#           [ 14,  12,  11],
#           [ 14,  12,  11],
#           ...,
#           [178, 174, 179],
#           [168, 167, 169],
#           [161, 160, 162]],
#
#          [[ 15,  13,  12],
#           [ 15,  13,  12],
#           [ 15,  13,  12],
#           ...,
# ...
#   array([[[182, 184, 192],
#           [183, 185, 193],
#           [184, 186, 194],
#           ...,
#           [140, 170, 181],
#           [140, 170, 181],
#           [138, 170, 181]],
#
#          [[180, 182, 190],
#           [181, 183, 191],
#           [182, 184, 192],
#           ...,
#           [140, 170, 181],
#           [140, 170, 181],
#           [138, 170, 181]],
#
#          [[180, 182, 190],
#           [180, 182, 190],
#           [181, 183, 191],
#           ...,
#           [140, 170, 181],
#           [140, 170, 181],
#           [140, 170, 181]],
#
#          ...,
#
#          [[ 25,  29,  18],
#           [ 13,  14,   4],
#           [ 18,  17,   7],
#           ...,
#           [139, 164, 180],
#           [139, 164, 180],
#           [140, 166, 182]],
#
#          [[ 83,  88,  79],
#           [ 40,  45,  36],
#           [ 17,  20,  11],
#           ...,
#           [138, 164, 180],
#           [139, 165, 181],
#           [140, 166, 182]],
#
#          [[157, 164, 157],
#           [ 83,  90,  83],
#           [ 30,  32,  26],
#           ...,
#           [140, 166, 182],
#           [141, 167, 183],
#           [140, 166, 182]]], dtype=uint8),
#   array([[[183, 144,  76],
#           [185, 147,  83],
#           [192, 157, 101],
#           ...,
#           [ 54,  21,   1],
#           [ 62,  21,   0],
#           [ 95,  51,  28]],
#
#          [[255, 222, 160],
#           [255, 228, 169],
#           [255, 234, 184],
#           ...,
#           [129,  96,  76],
#           [ 85,  44,  22],
#           [ 74,  30,   7]],
#
#          [[255, 245, 196],
#           [255, 240, 193],
#           [255, 231, 189],
#           ...,
#           [145, 114,  93],
#           [145, 106,  84],
#           [ 89,  47,  24]],
#
#          ...,
#
#          [[175, 105,  12],
#           [150,  89,   9],
#           [210, 168, 115],
#           ...,
#           [159,  59,   0],
#           [165,  65,   1],
#           [166,  67,   5]],
#
#          [[175, 106,   3],
#           [160, 100,  11],
#           [159, 118,  56],
#           ...,
#           [162,  64,   0],
#           [163,  65,   1],
#           [162,  65,   1]],
#
#          [[156,  88,   0],
#           [168, 110,  15],
#           [219, 177, 112],
#           ...,
#           [158,  59,   0],
#           [157,  60,   0],
#           [158,  61,   0]]], dtype=uint8),
#   array([[[ 19,  19,  33],
#           [ 32,  32,  46],
#           [ 35,  35,  49],
#           ...,
#           [ 51,  49,  49],
#           [ 51,  49,  49],
#           [ 51,  49,  49]],
#
#          [[ 22,  22,  36],
#           [ 30,  30,  44],
#           [ 27,  27,  41],
#           ...,
#           [ 49,  47,  47],
#           [ 49,  47,  47],
#           [ 49,  47,  47]],
#
#          [[ 25,  25,  37],
#           [ 25,  25,  37],
#           [ 24,  24,  36],
#           ...,
#           [ 50,  48,  48],
#           [ 50,  48,  48],
#           [ 52,  50,  50]],
#
#          ...,
#
#          [[ 27,  29,  29],
#           [ 34,  36,  36],
#           [ 41,  41,  41],
#           ...,
#           [121, 113, 113],
#           [100,  92,  92],
#           [ 75,  67,  67]],
#
#          [[ 29,  31,  31],
#           [ 36,  38,  38],
#           [ 41,  41,  41],
#           ...,
#           [230, 225, 224],
#           [228, 223, 222],
#           [189, 184, 183]],
#
#          [[ 30,  32,  32],
#           [ 36,  38,  38],
#           [ 38,  38,  38],
#           ...,
#           [204, 199, 198],
#           [255, 255, 254],
#           [254, 249, 248]]], dtype=uint8),
#   array([[[50, 42, 35],
#           [47, 39, 32],
#           [42, 34, 27],
#           ...,
#           [58, 49, 45],
#           [58, 49, 45],
#           [59, 50, 46]],
#
#          [[53, 45, 38],
#           [50, 42, 35],
#           [47, 39, 32],
#           ...,
#           [67, 58, 54],
#           [68, 59, 55],
#           [68, 59, 55]],
#
#          [[56, 48, 41],
#           [55, 47, 40],
#           [53, 45, 38],
#           ...,
#           [82, 73, 69],
#           [82, 73, 69],
#           [82, 73, 69]],
#
#          ...,
#
#          [[46, 36, 36],
#           [48, 38, 38],
#           [51, 41, 41],
#           ...,
#           [57, 48, 45],
#           [55, 46, 43],
#           [53, 44, 41]],
#
#          [[46, 36, 36],
#           [49, 39, 39],
#           [52, 42, 42],
#           ...,
#           [56, 47, 44],
#           [54, 45, 42],
#           [52, 43, 40]],
#
#          [[47, 37, 37],
#           [49, 39, 39],
#           [52, 42, 42],
#           ...,
#           [56, 47, 44],
#           [53, 44, 41],
#           [51, 42, 39]]], dtype=uint8),
#   array([[[ 89,  85,  90],
#           [115, 111, 116],
#           [ 91,  87,  92],
#           ...,
#           [116, 107, 110],
#           [ 97,  88,  91],
#           [ 87,  78,  81]],
#
#          [[ 50,  46,  51],
#           [ 47,  43,  48],
#           [ 74,  70,  75],
#           ...,
#           [ 83,  74,  77],
#           [ 84,  75,  78],
#           [ 82,  73,  76]],
#
#          [[ 35,  31,  36],
#           [ 16,  12,  17],
#           [100,  96, 101],
#           ...,
#           [  7,   0,   1],
#           [ 49,  40,  43],
#           [ 71,  62,  65]],
#
#          ...,
#
#          [[ 33,  27,  38],
#           [ 32,  27,  36],
#           [ 59,  53,  64],
#           ...,
#           [ 11,   8,  10],
#           [ 47,  44,  46],
#           [ 79,  76,  78]],
#
#          [[ 15,  10,  19],
#           [ 49,  45,  51],
#           [ 66,  61,  70],
#           ...,
#           [113, 108, 110],
#           [123, 118, 120],
#           [ 98,  93,  95]],
#
#          [[ 18,  14,  20],
#           [ 52,  48,  54],
#           [ 69,  65,  71],
#           ...,
#           [128, 123, 125],
#           [137, 132, 134],
#           [110, 105, 107]]], dtype=uint8)],
#  array(['A7814', 'B1074QO', 'B1031QO', 'B187EDA', 'B1089VD', 'B1972RBP',
#         'AB2400WU', 'AB6268YQ', 'A8014VA', 'B1554EJA', 'B1160BH',
#         'B1032PJE', 'B173PUT', 'B111HSN', 'B1254TFX', 'B1618WYJ',
#         'AD6850RD', 'B1717UUA', 'B1903RFD', 'B1697ELS', 'B1119ZB',
#         'B1021KIF', 'B1566FON', 'B1578SJL', 'B1075QO', 'AB6691FU',
#         'B1860EFT', 'B1254TFX', 'B1684BJN', 'A1565E', 'B104WSP',
#         'B1946TKN', 'B1629SJN', 'B1157', 'AB1727MN', 'B1144ERW',
#         'B1732PJH', 'B1926WYF', 'B1269EZD', 'AB5571SA', 'B1691TMU',
#         'B1289QQ', 'B1773UL', 'AD8746OF', 'A8014VA', 'AB4158TE',
#         'B1295TJD', 'B1078QO', 'B1898STA', 'B1184TJD', 'B1652UN',
#         'B1819CKF', 'B1874TLP', 'AE5477RN', 'B1941SRE', 'AD9550BV',
#         'A9192ZM', 'B1596ELO', 'A8014VA', 'B1312SIM', 'AA8414PB',
#         'B1174NRQ', 'AD6259QQ', 'AB6677RU', 'AB3650BZ', 'B1074QO',
#         'B1739TZI', 'B1541SEP', 'B1487VD', 'B1102SIV', 'B1145TIV',
#         'B1028QO', 'AE1624CA', 'A9590B', 'B1067SFP', 'B1642SZL',
#         'B1871TIG', 'AA6290HL', 'AE4996VI', 'B1661TKZ', 'B1634TZJ',
#         'AB6941JE', 'B1419EZE', 'B1MAM', 'AD9313SS', 'B1019TIN',
#         'B1020ERF', 'B1016WBF', 'B1036UL', 'B1297POS', 'B1593UN',
#         'B1697TBB', 'B1946TKN', 'AA8144CF', 'AB5571SA', 'B129JE',
#         'AE2593NZ', 'AA8527BT', 'B1326RFD', 'AB2301VW', 'A9590B',
#         'A8055KJ', 'B1136UZU', 'B1876BKK', 'AA1856CJ', 'AB3767XY',
#         'A1565DT', 'AB2241VY', 'B1887KRS', 'B1248PC', 'B1340UL', 'A9583B',
#         'B1029QH', 'B1487VD', 'B1236QZ', 'B1668B', 'B1211RKA', 'B1747',
#         'B1522EZG', 'B1454EYF', 'AD3864WI', 'B1880ZKE', 'B1806UTC',
#         'B1305AMI', 'AA7126FF', 'A9388EX', 'AIIS', 'B1339UL', 'AB2532QU',
#         'AB6711MQ', 'B1280QO', 'B1045WMU', 'B1630UJY', 'B1218TLQ',
#         'B1617RFP', 'AA7211QO', 'A7692KC', 'AB2025XA', 'B1221UAD',
#         'B1937TAG', 'B1495QO', 'B1472PQH', 'B1040UN', 'B1042PJ',
#         'B1679TJU', 'B1419EZE', 'B1781TJW', 'B1486RFS', 'B1902TOX',
#         'B1460TIQ', 'B1198TJS', 'B1289QO', 'B1117KVE', 'B130ER', 'A8014VA',
#         'B1786BKG', 'A9388EX', 'B1015SJW', 'B1493KIE', 'B1378EM',
#         'B1868LK', 'B1669TFL', 'B1753UJQ', 'B1827TRK', 'B1241PQO',
#         'B1166UUA', 'A7693KC', 'B139RFS', 'B1079ZKM', 'B16TB', 'B0120KXT',
#         'AG2020WS', 'B1383SS', 'B1783NKV', 'AA9122J', 'B1895EJB',
#         'B1321GQ', 'AB2070', 'B1028QO', 'B1588EKZ', 'B1296TJR', 'AE9562NJ',
#         'B1006UL', 'B1209BOE', 'B1157SSL', 'B1547UIW', 'B1248PC',
#         'B1739TZI', 'B116NAU', 'AB6729NC', 'B1245UVK', 'AB2873WI',
#         'B1813TYD', 'B1063SJQ', 'B1859ZEA', 'B1157YO', 'B1468TYU',
#         'B1855SLD', 'AA2658RN', 'B1797TJS', 'B1697SJO', 'B1820TJV',
#         'B1808TU', 'B1245UVK', 'B1184SSR', 'AA4314HV', 'B102HHB',
#         'B1131EKG', 'B1070QO', 'AD6562RT', 'B1946TKN', 'AG9424UO',
#         'B1343SKR', 'B1157Y', 'B1408NYW', 'B1MAM', 'B1899ERZ', 'B1868LK',
#         'B1574WKH', 'B102HHB', 'AA4280RL', 'B116NAU', 'B1167UM',
#         'B1941SRE', 'B1380RFJ', 'AB2056IY', 'B1050SJK', 'B1152ZLQ',
#         'B1641KOT', 'B1352TRU', 'B1897NKN', 'B111HSN', 'AD3340OJ',
#         'B1330VD', 'B1289QO', 'AD99JR', 'AD4746NW', 'B1486TJJ', 'B1545UJL',
#         'B1487VD', 'B1242VMC', 'B1375TFG', 'B1598TMZ', 'B1549RFS',
#         'B1460TIO', 'A1818FS', 'B1151TMO', 'B1702ERJ', 'AB6923UE',
#         'B187EDA', 'B1102SIV', 'A9583B', 'B1125VY', 'AD418U', 'B1309SRU',
#         'B1265FFK', 'A9585B', 'A317', 'AB6041DH', 'A7692KC', 'B1345QO',
#         'B1772TOZ', 'AA4545DJ', 'B1311UVL', 'B1260UL', 'B1260TZT',
#         'B1089VD', 'B1505NJW', 'B1781TJW', 'B1040UN', 'B1925KEP',
#         'AA1248MB', 'B1617QZ', 'B1542TJT', 'B1898STA', 'B1340UL',
#         'B1588EKZ', 'B1819UL', 'B0120KXT', 'B1015SJW', 'B1012DFM',
#         'B1216TRD', 'B1855EYB', 'B1794PJG', 'AB1288RE', 'B1207TJW',
#         'B1581BYB', 'B1549RFS', 'B1028QO', 'B1135SGM', 'B1765ERB',
#         'B1203BF', 'A1398BC', 'B1314PVF', 'B1583UN', 'B1490ZFV', 'B1340QO',
#         'B116NAU', 'B1598QH', 'AB8644PK', 'B1123UL', 'AD5423AID', 'B11VAN',
#         'A8014VA', 'B090VD', 'B1392RFW', 'AB1352TQ', 'B1468TYU', 'B1820UL',
#         'AG1136LN', 'B1840TJK', 'B1908F', 'A8014VA', 'B1682PJN',
#         'B1358VLP', 'B1051SMK', 'B1258PFL', 'B1032PJE', 'B1158FCR',
#         'B124SAA', 'B1198TJS', 'B1210DFO', 'A7692KC', 'B1183TOL',
#         'AG8157U', 'B1032NJH', 'B1254TFX', 'B1451UN', 'AB1280TT',
#         'B1661TKZ', 'A9590B', 'B1495QO', 'B1642SZL', 'B1349TLR', 'B1652UN',
#         'B1280QO', 'B1029GKI', 'B1339UJP', 'B1713MT', 'B1242VMC',
#         'B1913TIS', 'B1887KRS', 'B1058WYD', 'B1040UN', 'AA1248MB',
#         'B1707RFS', 'B1673UZG', 'B1654RFS', 'B1868LK', 'B1110WW',
#         'B1063SJQ', 'B1093FIB', 'AB1449KB', 'B1930TKI', 'AG1855VX',
#         'B1642SZL', 'B1571SMD', 'B1089VD', 'B1MAM', 'B1487VD', 'B19EDY',
#         'AD1164HU', 'B090VD', 'B1593TZH', 'B1921UJQ', 'B1073QO', 'B1713',
#         'AG4134XR', 'B1439TJY', 'AA4792SN', 'B1213NVK', 'B1770TKL',
#         'B1969SJD', 'B1412RFJ', 'AB6401RI', 'B1458TBD', 'B1652UN',
#         'B1732SMJ', 'A6973MS', 'B1046HI', 'B1453ZKB', 'B1562PI', 'A8912VX',
#         'B1482FRS', 'B1825KJN', 'B1743FYP', 'B1741TJT', 'B1089VD',
#         'B1169SJE', 'B188PMJ', 'B1633BW', 'AG5140VAA', 'AD418U', 'B1484QH',
#         'AE9562NJ', 'B1563UL', 'AB5537QJ', 'B1834KMQ', 'AE7296XA',
#         'B1259JUE', 'B1586WFJ', 'B1528DR', 'B1470TLQ', 'B1112GJ',
#         'B1855EYB', 'B1439TJY', 'B1873YU', 'B1736UZX', 'B1166UUA',
#         'B1912RFS', 'B1063SJQ', 'B1032PJE', 'AE7023UP', 'B1378TYD',
#         'B1076Y', 'B17QO', 'B1389TJT', 'B1282TJB', 'B1970NO', 'B1774TIT',
#         'B1MAM', 'B1388FOC', 'B1921TJW', 'A1565DT', 'B1755KZI', 'B1159PQB',
#         'AD8746OF', 'B1752FZI', 'AB6758ZY', 'B1276RKA', 'B1184TJD',
#         'AB5915KJ', 'A9583B', 'B1634TZJ', 'B1493QO', 'B123MBM', 'B1499UL',
#         'B1753UJQ', 'AD1164HU', 'B1122HL', 'AB6620NZ', 'B1276PVE',
#         'B1276TJH', 'B1794TZF', 'B1642SZL', 'B1826UOI', 'AG7078UI',
#         'B1754NYJ', 'B1855SL0', 'B1191PJT', 'B1819UL', 'B1226TZY',
#         'AB2314XY', 'B1652UN', 'B1819U', 'AD8594TU', 'B19EDY', 'B128000',
#         'B1423KZR', 'B1684BJN', 'B1755KZI', 'AB4331SJ', 'AB2491TQ',
#         'AG815U', 'B1487', 'AB2613WC', 'AB5152KJ', 'B1125OP', 'B1920TJM',
#         'AG5253PH', 'B1398TJL', 'B1057ERC', 'B1433DVK', 'B1494TYU',
#         'B1953TJW', 'B1869EOF', 'AB5701ZJ', 'B1091PJK', 'B1830PJK',
#         'B1916SJJ', 'B1021UJB', 'B1765ERB', 'B1276RKA', 'B1864BOM',
#         'B1861QH', 'B1220SOJ', 'B9749TIS', 'B1136NJH', 'AA2950UG',
#         'AD8626VD', 'AD8820CB', 'B1184SSR', 'B1212WZ', 'AB2636ZU',
#         'B1717KI', 'A8763AE', 'B1961OA', 'AB3576XY', 'B1965RO', 'AD8714QT',
#         'B1770TIC', 'B1977QZ', 'AD4995CZ', 'B1568VD', 'B1732PJH',
#         'B1754EZF', 'B1523NYT', 'AG956IKI', 'B1425VOM', 'B144NTA',
#         'B1972RBP', 'B1739TZI', 'B13NST', 'B1404GT', 'B1231UIR',
#         'B1114WZL', 'AB3887NL', 'B1969SJD', 'B1064TFR', 'B1926WYF',
#         'B1980VD', 'B1487', 'B1340QO', 'B1028QO', 'A9590B', 'B1946TKN',
#         'B1047QO', 'B1209TJY', 'B1469TJJ', 'AD8746OF', 'B1830DFD',
#         'AG7078UI', 'AB3511OH', 'B1863WW', 'B1124SQ', 'AA3509FN',
#         'B1538ELS', 'AA9080CK', 'B1643TRO', 'B1594ULP', 'AB2154EA',
#         'B1877TJV', 'AB6066MF', 'B1394SMH', 'A8127J', 'B1451UN',
#         'B1160RFK', 'B1225FIS', 'B1196BKK', 'AB1170UU', 'B1248FZN',
#         'B1855SLO', 'B1047QO', 'B1236QZ', 'AB6050JB', 'B1112SFO',
#         'B1693EYM', 'B1358VLP', 'AB3287UI', 'B1946VMF', 'B1185NJA',
#         'B1038TZC', 'B1311UVL', 'B1939FRA', 'B1964VD', 'B1169TJK',
#         'B1509FMW', 'B1157YU', 'AD1124SD', 'B1276TJH', 'B188SIP',
#         'AD9019IU', 'AD2212BK', 'AB2546LT', 'B1073QO', 'B1254TFX',
#         'B184HMD', 'B1278EJ', 'AB1449DH', 'B1340UL', 'B1101KJO',
#         'B1324EON', 'B1763QT', 'B1059RFS', 'B1744UN', 'AB6213QF',
#         'B1112GJ', 'B1776EVE', 'AD8888KJ', 'B1830PJK', 'B1063SJQ',
#         'AD9077PR', 'B19EDY', 'B1921UJQ', 'AD8746OF', 'B1632TJJ',
#         'B1330VD', 'B1545CL', 'B1774TIT', 'AA4792SN', 'B130900',
#         'B1229EYO', 'AA4314HV', 'B1937WJD', 'B1033PQN', 'A9529ZB',
#         'AB2765LL', 'B1691TMU', 'B1390TMF', 'AA510LE', 'B1006UL',
#         'B1786UJT', 'AB5701ZJ', 'B118GY', 'B1819UL', 'A7692KC', 'B1946TKN',
#         'B1439TJY', 'B1592TJP', 'B1289QO', 'B1020SCZ', 'B1439TJY',
#         'AB6094XE', 'B1160BH', 'B1626KJM', 'AB5410YQ', 'AB7020RA',
#         'B1509UN', 'B1665WJD', 'B1378EFZ', 'B1980VD', 'B1061PJT',
#         'B1692EYC', 'AD418U', 'B1801TZS', 'B1568VD', 'B1430COI',
#         'B1050VKK', 'B1164EMZ', 'B1470TLO', 'B1547UIW', 'B1879TFO',
#         'B1802EOZ', 'B1NTK', 'B1980VD', 'B1895WLT', 'B1159TJF', 'B1323NYX',
#         'B1758KRX', 'B1100SZO', 'B1494BJK', 'B1045WMU', 'B1794PJG',
#         'B1389TJT', 'B1578SJL', 'B1128BYT', 'AB2613WC', 'B1100SZD',
#         'B1260UL', 'B1074QO', 'AD6118BFE', 'B1080PED', 'B1445TIF',
#         'B1508EZE', 'B1925SYG', 'B1201QO', 'AB8861FD', 'B1073QO',
#         'A5822BG', 'B1578TJI', 'B1253BAC', 'B1713M', 'B1031QO', 'B1770TKL',
#         'B1433UN', 'B121PQO', 'B1633BW', 'AE7296XA', 'B1672KVF',
#         'B1815TJQ', 'B1690ZKL', 'B1252NZD', 'B15MAH', 'AB3351ZU',
#         'B1560UN', 'B1670TLR', 'B1833TVG', 'B1486RFS', 'B1229EYO',
#         'AB1195FX', 'B1820UL', 'AG8548EH', 'B1102PZW', 'B1682SJI',
#         'AB4131ME', 'B1963TFU', 'A9529ZB', 'B1058YEB', 'B1658YU',
#         'B1532NKY', 'A7693KC', 'B1408RX', 'B1326TMS', 'B1322BFD',
#         'B1559UN', 'B1339UL', 'B1152ZLQ', 'B1239TJP', 'AB4150KE', 'A9583B',
#         'B1672KVF', 'B1339RFD', 'B1767TJR', 'B178QO', 'AB6019KK',
#         'B1603BVK', 'AD6259QQ', 'B1817UL', 'B1457TJI', 'B1509POQ',
#         'B1739TZI', 'B1658KRF', 'B1358VLP', 'B1036EYB', 'B017QO',
#         'B1310EMS', 'B1642TRW', 'B1543VOS', 'B1310SZL', 'B1312SJO',
#         'AD9112BZ', 'B1047QO', 'B1877TJV', 'B1641VOR', 'B1641KOT',
#         'B1392TJV', 'B1646EYO', 'AB2231AT', 'AD1558BN', 'B1336PIZ',
#         'B1860KQ', 'B1690ZKL', 'B1502UN', 'B1757VKB', 'B1038TZC',
#         'B1614TJR', 'AB6506CD', 'AB6315SE', 'B1278EJ', 'AF1235FQ',
#         'B1047QO', 'B1977QZ', 'B1481UJV', 'B1076Y', 'B1210DFO', 'B1361TJS',
#         'B1975FEA', 'B1682PJN', 'B1770TKL', 'B13NST', 'B1305UL',
#         'AG5836RBV', 'AD9077PR', 'B1817UL', 'B1502SYQ', 'B1330NK',
#         'B1877TJV', 'B1738VFV', 'AD9112BZ', 'AB6018HU', 'B1330NK',
#         'B1719BYN', 'AB1861XN', 'A8014VA', 'B1274BJB', 'B1963TFU',
#         'B1674TJK', 'B1690BAC', 'B1964VD', 'B16BW', 'A7703KC', 'B1160RFK',
#         'B1512NRN', 'B1538ELS', 'A1398BC', 'B1559UN', 'B1913TIS',
#         'B1619UL', 'AB1164PU', 'AB1473RI', 'B1802EOZ', 'A8815VX',
#         'B1187FJH', 'AB1364AN', 'B1269MA', 'B1677EJC', 'B1743VO',
#         'AD1416YD', 'AB5419TN', 'AB6315SE'], dtype=object))
